# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
vec1 = np.random.rand(10000) #two vectors of random numbers
vec2 = np.random.rand(10000)
vec = vec1/vec2 #find the difference
for i in range(len(vec)): #take just the first digit, excluding 0 in decimals
    num = vec[i]
    first_dig = int(f'{num:E}'[0])
    vec[i] = first_dig

# %%
e = pd.value_counts(vec,normalize=True) #count frequency that a digit comes up

# %%
benford = []
for i in range (1,10):
    benford.append(np.log10((i+1)/i)) #calculate the values through benfords law

# %%
benford
# Out:
# [0.3010299956639812,
#  0.17609125905568124,
#  0.12493873660829993,
#  0.09691001300805642,
#  0.07918124604762482,
#  0.06694678963061322,
#  0.05799194697768673,
#  0.05115252244738129,
#  0.04575749056067514]

# %%
plt.plot(benford,e.values) #plot versus a straight line to show how close it is
plt.plot(benford,benford)
